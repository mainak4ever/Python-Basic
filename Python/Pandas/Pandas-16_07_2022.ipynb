# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.random.randn(3,3),columns=['one','two','three'])

# %%
df
# Out:
#         one       two     three
# 0  1.068203 -1.224109 -0.810568
# 1 -0.122384  0.760334 -0.279911
# 2  0.097951 -1.879415  0.015663

# %%
df.max()
# Out:
# one      1.068203
# two      0.760334
# three    0.015663
# dtype: float64

# %%
df.min()
# Out:
# one     -0.122384
# two     -1.879415
# three   -0.810568
# dtype: float64

# %%
df.max()-df.min()
# Out:
# one      1.190587
# two      2.639749
# three    0.826231
# dtype: float64

# %%
#Syntax
# dataframe.apply(FUNCION)

# %%
def custom(data):
    maximum=data.max()
    minimum=data.min()
    return maximum-minimum

# %%
df.apply(custom) #column wise
# Out:
# one      1.190587
# two      2.639749
# three    0.826231
# dtype: float64

# %%
df.apply(custom,axis=1) #row wise
# Out:
# 0    2.292312
# 1    1.040245
# 2    1.977367
# dtype: float64

# %%
# Ghost function or lambda function

# %%
# lambda input : output

# %%
f= lambda data: data.max()- data.min()

# %%
df.apply(f) #column wise
# Out:
# one      1.190587
# two      2.639749
# three    0.826231
# dtype: float64

# %%
df.apply(lambda data: data.max()- data.min())
# Out:
# one      1.190587
# two      2.639749
# three    0.826231
# dtype: float64

# %%
df
# Out:
#         one       two     three
# 0  1.068203 -1.224109 -0.810568
# 1 -0.122384  0.760334 -0.279911
# 2  0.097951 -1.879415  0.015663

# %%
df['four']=df['three'].apply(lambda x: x**3)

# %%
df
# Out:
#         one       two     three      four
# 0  1.068203 -1.224109 -0.810568 -0.532560
# 1 -0.122384  0.760334 -0.279911 -0.021931
# 2  0.097951 -1.879415  0.015663  0.000004

# %%
def cust(row):
    return row**3

# %%
df['three'].apply(cust)
# Out:
# 0   -0.532560
# 1   -0.021931
# 2    0.000004
# Name: three, dtype: float64

# %%
df=pd.DataFrame(np.random.randn(30,3),columns=['one','two','three'])

# %%
#subset
df[df['one']>0]['three'].apply(lambda x: x**3)
# Out:
# 1      0.115845
# 2      0.510525
# 4     -0.071271
# 5      2.139658
# 6     -0.223030
# 13   -11.928793
# 15     0.461285
# 16     0.025651
# 17    -1.306981
# 18    -0.057988
# 20    -1.136651
# 21    -1.782036
# 22     2.240676
# 26    -0.004182
# 29    -0.014327
# Name: three, dtype: float64

# %%
df.shape
# Out:
# (30, 3)

# %%
df['four']=df[df['one']>0]['three'].apply(lambda x: x**3)

# %%
df['one']=df[df['one']>0]['three'].apply(lambda x: x**3)

# %%
df
# Out:
#           one       two     three       four
# 0         NaN -0.935795  0.933106        NaN
# 1    0.115845  0.691023  0.487483   0.115845
# 2    0.510525 -0.808510  0.799231   0.510525
# 3         NaN  0.058236  0.698019        NaN
# 4   -0.071271 -0.271124 -0.414608  -0.071271
# 5    2.139658 -0.324409  1.288590   2.139658
# 6   -0.223030  0.630434 -0.606440  -0.223030
# 7         NaN  0.121235 -0.068915        NaN
# 8         NaN -0.235508 -0.981793        NaN
# 9         NaN -0.233796 -0.342366        NaN
# 10        NaN -0.595610  0.141327        NaN
# 11        NaN  0.575592 -0.062280        NaN
# 12        NaN -1.338767  0.612413        NaN
# 13 -11.928793  0.667112 -2.284891 -11.928793
# 14        NaN -0.229196 -1.323258        NaN
# 15   0.461285  0.098709  0.772662   0.461285
# 16   0.025651 -2.427092  0.294916   0.025651
# 17  -1.306981  1.973726 -1.093343  -1.306981
# 18  -0.057988  0.308956 -0.387061  -0.057988
# 19        NaN  1.193569 -0.445633        NaN
# ...

# %%
df['three'].apply(lambda x: x**3 if x >0 else x**2)
# Out:
# 0     0.812444
# 1     0.115845
# 2     0.510525
# 3     0.340096
# 4     0.171900
# 5     2.139658
# 6     0.367769
# 7     0.004749
# 8     0.963918
# 9     0.117214
# 10    0.002823
# 11    0.003879
# 12    0.229686
# 13    5.220727
# 14    1.751012
# 15    0.461285
# 16    0.025651
# 17    1.195399
# 18    0.149817
# 19    0.198589
# 20    1.089143
# 21    1.469866
# 22    2.240676
# 23    1.520606
# 24    3.576596
# 25    0.013652
# 26    0.025959
# 27    0.060227
# 28    5.102421
# 29    0.058990
# Name: three, dtype: float64

# %%
x=10

# %%
if x> 5:
    print("hey")
else:
    print("no")
# Out:
# hey

# %%
#comprehensions
print("hey") if x>15 else print("no")
# Out:
# no

# %%
df.describe()
# Out:
#              one        two      three       four
# count  15.000000  30.000000  30.000000  15.000000
# mean   -0.735441   0.040167  -0.290795  -0.735441
# std     3.278757   0.870396   0.969450   3.278757
# min   -11.928793  -2.427092  -2.284891 -11.928793
# 25%    -0.679840  -0.311088  -1.028163  -0.679840
# 50%    -0.014327   0.078472  -0.244146  -0.014327
# 75%     0.288565   0.616723   0.439341   0.288565
# max     2.240676   1.973726   1.308558   2.240676

# %%
def f(x):
    return pd.Series([np.mean(x), x.max(), x.min()], index=['mean','max','min'])

# df.apply(f, axis=1)
df.apply(f)
# Out:
#             one       two     three       four
# mean  -0.735441  0.040167 -0.290795  -0.735441
# max    2.240676  1.973726  1.308558   2.240676
# min  -11.928793 -2.427092 -2.284891 -11.928793

# %%
df2=pd.DataFrame(df.describe())

# %%
df2.reset_index()
# Out:
#    index        one        two      three       four
# 0  count  15.000000  30.000000  30.000000  15.000000
# 1   mean  -0.735441   0.040167  -0.290795  -0.735441
# 2    std   3.278757   0.870396   0.969450   3.278757
# 3    min -11.928793  -2.427092  -2.284891 -11.928793
# 4    25%  -0.679840  -0.311088  -1.028163  -0.679840
# 5    50%  -0.014327   0.078472  -0.244146  -0.014327
# 6    75%   0.288565   0.616723   0.439341   0.288565
# 7    max   2.240676   1.973726   1.308558   2.240676

# %%
df.cumsum()
# Out:
#           one       two     three       four
# 0         NaN -0.935795  0.933106        NaN
# 1    0.115845 -0.244772  1.420589   0.115845
# 2    0.626370 -1.053282  2.219820   0.626370
# 3         NaN -0.995047  2.917839        NaN
# 4    0.555099 -1.266171  2.503231   0.555099
# 5    2.694756 -1.590579  3.791821   2.694756
# 6    2.471726 -0.960145  3.185381   2.471726
# 7         NaN -0.838910  3.116466        NaN
# 8         NaN -1.074419  2.134673        NaN
# 9         NaN -1.308215  1.792307        NaN
# 10        NaN -1.903825  1.933634        NaN
# 11        NaN -1.328233  1.871353        NaN
# 12        NaN -2.667000  2.483767        NaN
# 13  -9.457066 -1.999888  0.198876  -9.457066
# 14        NaN -2.229084 -1.124383        NaN
# 15  -8.995781 -2.130375 -0.351720  -8.995781
# 16  -8.970131 -4.557466 -0.056804  -8.970131
# 17 -10.277112 -2.583740 -1.150147 -10.277112
# 18 -10.335100 -2.274784 -1.537208 -10.335100
# 19        NaN -1.081214 -1.982841        NaN
# ...

# %%
df2=pd.DataFrame(np.random.randint(1,10,size=(10,3)),columns=['one','two','three'])

# %%
df2
# Out:
#    one  two  three
# 0    6    3      4
# 1    8    2      1
# 2    7    6      7
# 3    5    4      7
# 4    9    4      6
# 5    5    8      3
# 6    2    2      3
# 7    2    9      9
# 8    6    1      4
# 9    6    2      3

# %%
df2.cumsum()
# Out:
#    one  two  three
# 0    6    3      4
# 1   14    5      5
# 2   21   11     12
# 3   26   15     19
# 4   35   19     25
# 5   40   27     28
# 6   42   29     31
# 7   44   38     40
# 8   50   39     44
# 9   56   41     47

# %%
df2.cumsum(axis=1)
# Out:
#    one  two  three
# 0    6    9     13
# 1    8   10     11
# 2    7   13     20
# 3    5    9     16
# 4    9   13     19
# 5    5   13     16
# 6    2    4      7
# 7    2   11     20
# 8    6    7     11
# 9    6    8     11

# %%
for i in df2.columns:
    new_col="cum_"+i
    df2[new_col]=df2[i].cumsum()

# %%
df2
# Out:
#    one  two  three  cum_one  cum_two  cum_three  cum_cum_one
# 0    6    3      4        6        3          4            6
# 1    8    2      1       14        5          5           20
# 2    7    6      7       21       11         12           41
# 3    5    4      7       26       15         19           67
# 4    9    4      6       35       19         25          102
# 5    5    8      3       40       27         28          142
# 6    2    2      3       42       29         31          184
# 7    2    9      9       44       38         40          228
# 8    6    1      4       50       39         44          278
# 9    6    2      3       56       41         47          334

# %%
left_frame = pd.DataFrame({'key': range(5), 
                           'left_value': ['a', 'b', 'c', 'd', 'e']})
right_frame = pd.DataFrame({'key': range(2, 7), 
                           'right_value': ['f', 'g', 'h', 'i', 'j']})
print(left_frame)
print()
print(right_frame)
# Out:
#    key left_value
# 0    0          a
# 1    1          b
# 2    2          c
# 3    3          d
# 4    4          e
#
#    key right_value
# 0    2           f
# 1    3           g
# 2    4           h
# 3    5           i
# 4    6           j

# %%
left_frame
# Out:
#    key left_value
# 0    0          a
# 1    1          b
# 2    2          c
# 3    3          d
# 4    4          e

# %%
right_frame
# Out:
#    key right_value
# 0    2           f
# 1    3           g
# 2    4           h
# 3    5           i
# 4    6           j

# %%
pd.merge(left=left_frame,right=right_frame,on='key',how='inner')
# Out:
#    key left_value right_value
# 0    2          c           f
# 1    3          d           g
# 2    4          e           h

# %%
pd.merge(left=left_frame,right=right_frame,on='key',how='left')
# Out:
#    key left_value right_value
# 0    0          a         NaN
# 1    1          b         NaN
# 2    2          c           f
# 3    3          d           g
# 4    4          e           h

# %%
pd.merge(left=left_frame,right=right_frame,on='key',how='right')
# Out:
#    key left_value right_value
# 0    2          c           f
# 1    3          d           g
# 2    4          e           h
# 3    5        NaN           i
# 4    6        NaN           j

# %%
pd.merge(left=left_frame,right=right_frame,on='key',how='outer')
# Out:
#    key left_value right_value
# 0    0          a         NaN
# 1    1          b         NaN
# 2    2          c           f
# 3    3          d           g
# 4    4          e           h
# 5    5        NaN           i
# 6    6        NaN           j

# %%
s1 = pd.DataFrame({'s1_key': range(5), 
                           'left_value': ['a', 'b', 'c', 'd', 'e']})
s2 = pd.DataFrame({'s2_key': range(2, 7), 
                           'right_value': ['f', 'g', 'h', 'i', 'j']})

# %%
s1
# Out:
#    s1_key left_value
# 0       0          a
# 1       1          b
# 2       2          c
# 3       3          d
# 4       4          e

# %%
s2
# Out:
#    s2_key right_value
# 0       2           f
# 1       3           g
# 2       4           h
# 3       5           i
# 4       6           j

# %%
pd.merge(left=s1,right=s2,left_on='s1_key',right_on='s2_key',how='inner')
# Out:
#    s1_key left_value  s2_key right_value
# 0       2          c       2           f
# 1       3          d       3           g
# 2       4          e       4           h

# %%
s1 = pd.DataFrame({'key': range(5), 
                           'value': ['a', 'b', 'c', 'd', 'e']})
s2 = pd.DataFrame({'key': range(2, 7), 
                           'value': ['c', 'd', 'c', 'd', 'j']})

# %%
s1
# Out:
#    key value
# 0    0     a
# 1    1     b
# 2    2     c
# 3    3     d
# 4    4     e

# %%
s2
# Out:
#    key value
# 0    2     c
# 1    3     d
# 2    4     c
# 3    5     d
# 4    6     j

# %%
pd.merge(s1,s2,on='key')
# Out:
#    key value_x value_y
# 0    2       c       c
# 1    3       d       d
# 2    4       e       c

# %%
pd.merge(left=pd.merge(s1,s2,on='key'),right=left_frame,on='key')
# Out:
#    key value_x value_y left_value
# 0    2       c       c          c
# 1    3       d       d          d
# 2    4       e       c          e

# %%
pd.concat([s1,s2])
# Out:
#    key value
# 0    0     a
# 1    1     b
# 2    2     c
# 3    3     d
# 4    4     e
# 0    2     c
# 1    3     d
# 2    4     c
# 3    5     d
# 4    6     j

# %%
pd.concat([s1,s2],axis=1)
# Out:
#    key value  key value
# 0    0     a    2     c
# 1    1     b    3     d
# 2    2     c    4     c
# 3    3     d    5     d
# 4    4     e    6     j

# %%
pd.concat([s1,s2,left_frame,right_frame])
# Out:
#    key value left_value right_value
# 0    0     a        NaN         NaN
# 1    1     b        NaN         NaN
# 2    2     c        NaN         NaN
# 3    3     d        NaN         NaN
# 4    4     e        NaN         NaN
# 0    2     c        NaN         NaN
# 1    3     d        NaN         NaN
# 2    4     c        NaN         NaN
# 3    5     d        NaN         NaN
# 4    6     j        NaN         NaN
# 0    0   NaN          a         NaN
# 1    1   NaN          b         NaN
# 2    2   NaN          c         NaN
# 3    3   NaN          d         NaN
# 4    4   NaN          e         NaN
# 0    2   NaN        NaN           f
# 1    3   NaN        NaN           g
# 2    4   NaN        NaN           h
# 3    5   NaN        NaN           i
# 4    6   NaN        NaN           j

# %%
x=pd.concat([s1,s2],axis=1)

# %%
x.columns
# Out:
# Index(['key', 'value', 'key', 'value'], dtype='object')

# %%
s1 = pd.DataFrame({'key': range(5), 
                           'value': ['a', 'b', 'c', 'd', 'e']})
s2 = pd.DataFrame({'key': range(2, 7), 
                           'value': ['c', 'd', 'c', 'd', 'j']})

# %%
s1.join(s2,lsuffix='_l',how='inner')
# Out:
#    key_l value_l  key value
# 0      0       a    2     c
# 1      1       b    3     d
# 2      2       c    4     c
# 3      3       d    5     d
# 4      4       e    6     j

# %%
s1.join(s2,lsuffix='_l',how='inner',on='key')
# Out:
#    key_l value_l  key value
# 0      0       a    2     c
# 1      1       b    3     d
# 2      2       c    4     c
# 3      3       d    5     d
# 4      4       e    6     j

# %%
0 in s2['key'].values
# Out:
# False

# %%
0 in list(s2['key'])
# Out:
# False

# %%
s1[s1['key'].apply(lambda x : x not in list(s2['key']))]
# Out:
#    key value
# 0    0     a
# 1    1     b

# %%
# Out:
#    key value
# 0    0     a
# 1    1     b
# 2    2     c
# 3    3     d
# 4    4     e

# %%
pd.merge(left=s1,right=s2,on='key',how='left',indicator=True)
# Out:
#    key value_x value_y     _merge
# 0    0       a     NaN  left_only
# 1    1       b     NaN  left_only
# 2    2       c       c       both
# 3    3       d       d       both
# 4    4       e       c       both
