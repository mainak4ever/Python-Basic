# %%
import pandas as pd

# %%
housing=pd.read_csv("C:/Users/Mionak/Desktop/housing.csv")

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 [housing['id']==9126100861].count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
housing.count(housing['waterfront']>0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 housing.count(housing['waterfront']>0)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9852, in DataFrame.count(self, axis, level, numeric_only)
#    9782 def count(
#    9783     self, axis: Axis = 0, level: Level | None = None, numeric_only: bool = False
#    9784 ):
#    9785     """
#    9786     Count non-NA cells for each column or row.
#    9787
#    (...)
#    9850     dtype: int64
#    9851     """
# -> 9852     axis = self._get_axis_number(axis)
#    9853     if level is not None:
#    9854         warnings.warn(
#    9855             "Using the level keyword in DataFrame and Series aggregations is "
#    9856             "deprecated and will be removed in a future version. Use groupby "
#    (...)
#    9859             stacklevel=find_stack_level(),
# ...

# %%
housing['waterfront']>0
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: waterfront, Length: 21613, dtype: bool

# %%
wf.count(wfTrue)
# Out:
# C:\Users\Mionak\AppData\Local\Temp\ipykernel_12676\2112177917.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. ser.count(level=1) should use ser.groupby(level=1).count().
#   wf.count(True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 wf.count(True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1976, in Series.count(self, level)
#    1968     warnings.warn(
#    1969         "Using the level keyword in DataFrame and Series aggregations is "
#    1970         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#    1973         stacklevel=find_stack_level(),
#    1974     )
#    1975     if not isinstance(self.index, MultiIndex):
# ...

# %%
housing.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 housing.info('waterfront'>0)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
housing.loc[housing["price"]==max(housing["price"])]
# Out:
#               id             date    price  bedrooms  bathrooms  sqft_living  \
# 7252  6762700020  20141013T000000  7700000         6        8.0        12050
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252     27600     2.5           0     3  ...     13        8570
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252           3480      1910          1987    98102  47.6298 -122.323
#
#       sqft_living15  sqft_lot15
# 7252           3940        8800
#
# [1 rows x 21 columns]

# %%
housing.loc[housing["grade"]==10].count()
# Out:
# id               1134
# date             1134
# price            1134
# bedrooms         1134
# bathrooms        1134
# sqft_living      1134
# sqft_lot         1134
# floors           1134
# waterfront       1134
# view             1134
# condition        1134
# grade            1134
# sqft_above       1134
# sqft_basement    1134
# yr_built         1134
# yr_renovated     1134
# zipcode          1134
# lat              1134
# long             1134
# sqft_living15    1134
# sqft_lot15       1134
# dtype: int64

# %%
pd.isnull(housing).sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
housing.loc[housing["view"]==3].count()
# Out:
# id               510
# date             510
# price            510
# bedrooms         510
# bathrooms        510
# sqft_living      510
# sqft_lot         510
# floors           510
# waterfront       510
# view             510
# condition        510
# grade            510
# sqft_above       510
# sqft_basement    510
# yr_built         510
# yr_renovated     510
# zipcode          510
# lat              510
# long             510
# sqft_living15    510
# sqft_lot15       510
# dtype: int64

# %%
min(housing["price"])
# Out:
# 75000

# %%
housing.loc[housing["price"]==min(housing["price"])]
# Out:
#               id             date  price  bedrooms  bathrooms  sqft_living  \
# 1149  3421079032  20150217T000000  75000         1        0.0          670
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1149     43377     1.0           0     0  ...      3         670
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1149              0      1966             0    98022  47.2638 -121.906
#
#       sqft_living15  sqft_lot15
# 1149           1160       42882
#
# [1 rows x 21 columns]

# %%
housing.loc[housing["sqft_living"]==max(housing["sqft_living"])]
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 12777  1225069038  20140505T000000  2280000         7        8.0        13540
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 12777    307752     3.0           0     4  ...     12        9410
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 12777           4130      1999             0    98053  47.6675 -121.986
#
#        sqft_living15  sqft_lot15
# 12777           4850      217800
#
# [1 rows x 21 columns]

# %%
housing.loc[housing["price"]==max(housing["price"])]
# Out:
#               id             date    price  bedrooms  bathrooms  sqft_living  \
# 7252  6762700020  20141013T000000  7700000         6        8.0        12050
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252     27600     2.5           0     3  ...     13        8570
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252           3480      1910          1987    98102  47.6298 -122.323
#
#       sqft_living15  sqft_lot15
# 7252           3940        8800
#
# [1 rows x 21 columns]

# %%
housing.duplicated(subset=['id','zipcode','grade'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Length: 21613, dtype: bool

# %%
housing[housing.duplicated(['id','zipcode','grade'])]
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 94     6021501535  20141223T000000   700000         3       1.50         1580
# 314    4139480200  20141209T000000  1400000         4       3.25         4290
# 325    7520000520  20150311T000000   240500         2       1.00         1240
# 346    3969300030  20141229T000000   239900         4       1.00         1000
# 372    2231500030  20150324T000000   530000         4       2.25         2180
# ...           ...              ...      ...       ...        ...          ...
# 20181  7853400250  20150219T000000   645000         4       3.50         2910
# 20613  2724049222  20141201T000000   220000         2       2.50         1000
# 20670  8564860270  20150330T000000   502000         4       2.50         2680
# 20780  6300000226  20150504T000000   380000         4       1.00         1200
# 21581  7853420110  20150504T000000   625000         3       3.00         2780
#
# ...

# %%
housing.iloc[3:6,6:10]
# Out:
#    sqft_lot  floors  waterfront  view
# 3      5000     1.0           0     0
# 4      8080     1.0           0     0
# 5    101930     1.0           0     0

# %%
df = pd.DataFrame({'A':[34, 78, 54], 'B':[12, 67, 43]}, index=['r1', 'r2', 'r3'])

# %%
df
# Out:
#      A   B
# r1  34  12
# r2  78  67
# r3  54  43

# %%
df.loc['r2':'r3']
# Out:
#      A   B
# r2  78  67
# r3  54  43

# %%
pd.to_datetime(data['date'], format='%Y-%m-%d', utc=False, dayfirst=True
# Out:
#   Input In [64]
#     pd.to_datetime(data['date'], format='%Y-%m-%d', utc=False, dayfirst=True
#                                                                             ^
# SyntaxError: unexpected EOF while parsing

# %%
pd.to_datetime(housing['date'])
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21613, dtype: datetime64[ns]

# %%
pd.to_datetime(housing['date'], format='%Y-%m-%d', utc=False, dayfirst=True)
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21613, dtype: datetime64[ns]

# %%
pd.to_datetime(housing['date'])
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21613, dtype: datetime64[ns]

# %%
sample_list = [['Carl', 22],
['Martha', 25],
['Calvin', 12],
['Stuart', 15]
]

# %%
pd.DataFrame(sample_list, columns=['Name', 'Age'])
# Out:
#      Name  Age
# 0    Carl   22
# 1  Martha   25
# 2  Calvin   12
# 3  Stuart   15

# %%
pd.DataFrame(sample_list)
# Out:
#         0   1
# 0    Carl  22
# 1  Martha  25
# 2  Calvin  12
# 3  Stuart  15

# %%
sample_dict = {'Cristiano': ['Ronaldo','Man U', 801],
'Lionel': ['Messi','PSG', 758],
'Luis': ['Suarez','Atletico Madrid', 509],
'Robert': ['Lewandowski','Bayern Munich', 527],
'Zlatan': ['Ibrahimovic','AC Milan',553]
}

# %%
df1 = pd.DataFrame(sample_dict)
df1 = df1.transpose()
df1.reset_index(inplace = True)
df1.columns = ['First Name','Last Name', 'Club', 'Goals']

# %%
df1
# Out:
#   First Name    Last Name             Club Goals
# 0  Cristiano      Ronaldo            Man U   801
# 1     Lionel        Messi              PSG   758
# 2       Luis       Suarez  Atletico Madrid   509
# 3     Robert  Lewandowski    Bayern Munich   527
# 4     Zlatan  Ibrahimovic         AC Milan   553

# %%
sample_tuple = ([1, 'one', 3],
[2, 'two', 3],
[3, 'Three', 5],
[4, 'Four', 4],
[5, 'Five', 4])

# %%
pd.DataFrame(sample_tuple, columns=['Number', 'Number_text', 'txtlen'])
# Out:
#    Number Number_text  txtlen
# 0       1         one       3
# 1       2         two       3
# 2       3       Three       5
# 3       4        Four       4
# 4       5        Five       4

# %%
ascending = housing.sort_values('price', ascending=True)
descending = housing.sort_values('price', ascending=False)

# %%
ascending
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000    75000         1       0.00          670
# 15293    40000362  20140506T000000    78000         2       1.00          780
# 465    8658300340  20140523T000000    80000         1       0.75          430
# 16198  3028200080  20150324T000000    81000         2       1.00          730
# 8274   3883800011  20141105T000000    82000         3       1.00          860
# ...           ...              ...      ...       ...        ...          ...
# 1448   8907500070  20150413T000000  5350000         5       5.00         8000
# 4411   2470100110  20140804T000000  5570000         5       5.75         9200
# 9254   9208900037  20140919T000000  6885000         6       7.75         9890
# 3914   9808700762  20140611T000000  7062500         5       4.50        10040
# 7252   6762700020  20141013T000000  7700000         6       8.00        12050
#
# ...

# %%
housing.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
housing.std()
# Out:
# C:\Users\Mionak\AppData\Local\Temp\ipykernel_12676\2264156241.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   housing.std()
# id               2.876566e+09
# price            3.671272e+05
# bedrooms         9.300618e-01
# bathrooms        7.701632e-01
# sqft_living      9.184409e+02
# sqft_lot         4.142051e+04
# floors           5.399889e-01
# waterfront       8.651720e-02
# view             7.663176e-01
# condition        6.507430e-01
# grade            1.175459e+00
# sqft_above       8.280910e+02
# sqft_basement    4.425750e+02
# yr_built         2.937341e+01
# yr_renovated     4.016792e+02
# zipcode          5.350503e+01
# lat              1.385637e-01
# long             1.408283e-01
# sqft_living15    6.853913e+02
# sqft_lot15       2.730418e+04
# dtype: float64

# %%
housing[25:36], housing.loc[(housing["lat"] == 47.6168) & (housing["long"] == -122.045)]
# Out:
# (            id             date   price  bedrooms  bathrooms  sqft_living  \
#  25  1202000200  20141103T000000  233000         3       2.00         1710
#  26  1794500383  20140626T000000  937000         3       1.75         2450
#  27  3303700376  20141201T000000  667000         3       1.00         1400
#  28  5101402488  20140624T000000  438000         3       1.75         1520
#  29  1873100390  20150302T000000  719000         4       2.50         2570
#  30  8562750320  20141110T000000  580500         3       2.50         2320
#  31  2426039314  20141201T000000  280000         2       1.50         1190
#  32   461000390  20140624T000000  687500         4       1.75         2330
#  33  7589200193  20141110T000000  535000         3       1.00         1090
#  34  7955080270  20141203T000000  322500         4       2.75         2060
#  35  9547205180  20140613T000000  696000         3       2.50         2300
#
# ...

# %%
housing['Floor Area'] = housing['sqft_living'] + housing['sqft_lot'] + housing['sqft_basement'] + housing['sqft_above']

# %%
housing['Floor Area']
# Out:
# 0         8010
# 1        12382
# 2        11540
# 3         8920
# 4        11440
#          ...
# 21608     4191
# 21609    10433
# 21610     3390
# 21611     5588
# 21612     3116
# Name: Floor Area, Length: 21613, dtype: int64

# %%
A = pd.DataFrame([['Carl', 22],['Martha', 25],['Calvin', 12],['Stuart', 15]], columns=['Name', 'Age'])
B = pd.DataFrame([['Melvin', 25],['Martha', 34],['Lewis', 32],['Leo', 25]], columns=['Name', 'Age'])

# %%
nner = pd.merge(A, B, on='Age', how='inner')
outer = pd.merge(A, B, on='Age', how='outer')
left_outer = pd.merge(A, B, on='Age', how='left')
right_outer = pd.merge(A, B, on='Age', how='right')

# %%
housing['sqft_living'].corr(housing['sqft_above'])
# Out:
# 0.876596598681317
